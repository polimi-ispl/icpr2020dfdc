# %% [markdown]
# # Net fusion results analysis
# The notebook analyzes the results of fusing different models results in different combinations

# %% [markdown]
# ## Libraries loading

# %%
import os
import ntpath
import sys
if '../' not in sys.path:
    sys.path.append('../')
import pandas as pd
from pathlib import Path
from tqdm.notebook import tqdm
import sklearn.metrics as M
from sklearn.metrics import log_loss
from scipy.special import expit
import numpy as np
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, train_test_split
from itertools import combinations
from isplutils.utils import aggregate
from multiprocessing import Pool, cpu_count
import seaborn as sns
from p_tqdm import p_map

# %% [markdown]
# ## Parameters

# %%
results_root = Path('/nas/public/exchange/icpr2020/results/')
results_model_folder = list(results_root.glob('net-*'))
column_list = ['video', 'score', 'label']
do_distplot = False

# %% [markdown]
# ## Helper functions

# %%
def compute_metrics(df_res:pd.DataFrame,train_tag:str) -> dict:
    numreal = sum(df_res['label']==False)
    numfake = sum(df_res['label']==True
)
    
    netname = train_tag.split('net-')[1].split('_')[0]
    traindb = train_tag.split('traindb-')[1].split('_')[0]
    
    loss = M.log_loss(df_res['label'],expit(df_res['score']))
    acc = M.accuracy_score(df_res['label'],df_res['score']>0)
    accbal = M.balanced_accuracy_score(df_res['label'],df_res['score']>0)
    rocauc = M.roc_auc_score(df_res['label'],df_res['score'])
    
    res_dict = {'traintag':train_tag,
                'net':netname,
                'traindb': traindb,
                'testdb':testdb,'testsplit':testsplit,
                'numreal':numreal,'numfake':numfake,
                'loss':loss,
                'acc':acc,'accbal':accbal,
                'rocauc':rocauc} 
    return res_dict

def highlight_values(s):
    '''
    highlight the three lowest and highest values in a Series (min: [red, yellow, darkorange], max: [green, lime, aqua]).
    '''
    s_idx = np.argsort(s.values)
    style = [''] * len(s)
    style[s_idx[0]] = 'background-color: red'
#     style[s_idx[1]] = 'background-color: yellow'
#     style[s_idx[2]] = 'background-color: darkorange'
    style[s_idx[-1]] = 'background-color: green'
#     style[s_idx[-2]] = 'background-color: lime'
#     style[s_idx[-3]] = 'background-color: aqua'
    return style

# %% [markdown]
# ## Load data

# %%
# Load data in multi-index dataframe
if os.path.exists('data_frame_df.pkl'):
    data_frame_df = pd.read_pickle('data_frame_df.pkl')
    model_list = []
    for model_folder in tqdm(results_model_folder):
        dataset_list = []
        train_model_tag = model_folder.name
        model_results = model_folder.glob('*.pkl')
        for model_path in model_results:
            dataset_tag = os.path.splitext(ntpath.split(model_path)[1])[0]
            dataset_list.append(dataset_tag)
        model_list.append(train_model_tag)
else:
    data_model_list = []
    model_list = []
    for model_folder in tqdm(results_model_folder):
        data_dataset_list = []
        dataset_list = []
        train_model_tag = model_folder.name
        model_results = model_folder.glob('*.pkl')
        for model_path in model_results:
            netname = train_model_tag.split('net-')[1].split('_')[0]
            traindb = train_model_tag.split('traindb-')[1].split('_')[0]
            testdb, testsplit = model_path.with_suffix('').name.rsplit('_',1)
            dataset_tag = os.path.splitext(ntpath.split(model_path)[1])[0]
            df_frames = pd.read_pickle(model_path)[column_list]
            # Add info on training and test datasets
            df_frames['netname'] = netname
            df_frames['train_db'] = traindb
            df_frames['test_db'] = testdb
            df_frames['test_split'] = testsplit
            data_dataset_list.append(df_frames)
            dataset_list.append(dataset_tag)
        data_model_list.append(pd.concat(data_dataset_list, keys=dataset_list, names=['dataset']))
        model_list.append(train_model_tag)
    data_frame_df = pd.concat(data_model_list, keys=model_list, names=['model']).swaplevel(0, 1)
    data_frame_df.to_pickle('data_frame_df.pkl')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))

# %% [markdown]
# ### Eliminate cross-datasets experiments (we already know they don't work) and Xception

# %%
# data_frame_df = data_frame_df[data_frame_df['train_db']==data_frame_df['test_db']]
data_frame_df = data_frame_df[data_frame_df['test_split']=='test']
data_frame_df = data_frame_df[data_frame_df['netname'] != 'Xception']
model_list = [x for x in model_list if "Xception_" not in x]
dataset_list = [x for x in dataset_list if "_val" not in x]
data_frame_df
# Out:
#                                                                                                                                         video  \
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...            9206
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...            9206
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...            9206
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...            9206
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...            9206
# ...                                                                                                                                       ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg   zpujdfwivh.mp4
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg   zpujdfwivh.mp4
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg   zpujdfwivh.mp4
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg   zpujdfwivh.mp4
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg   zpujdfwivh.mp4
#
#                                                                                                                                   score  \
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...  3.556629
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  1.067607
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  3.871128
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  3.076689
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  4.006863
# ...                                                                                                                                 ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg   3.383530
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg   4.214155
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg   3.685401
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg  -0.509255
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg   3.152403
#
#                                                                                                                                label  \
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...   True
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...   True
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...   True
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...   True
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...   True
# ...                                                                                                                              ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg    True
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg    True
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg    True
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg    True
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg    True
#
#                                                                                                                                                netname  \
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...           EfficientNetB4
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...           EfficientNetB4
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...           EfficientNetB4
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...           EfficientNetB4
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...           EfficientNetB4
# ...                                                                                                                                                ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg   EfficientNetAutoAttB4ST
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg   EfficientNetAutoAttB4ST
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg   EfficientNetAutoAttB4ST
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg   EfficientNetAutoAttB4ST
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg   EfficientNetAutoAttB4ST
#
#                                                                                                                                          train_db  \
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
# ...                                                                                                                                           ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg         dfdc-35-5-10
#
#                                                                                                                                           test_db  \
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...  ff-c23-720-140-140
# ...                                                                                                                                           ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg         dfdc-35-5-10
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg         dfdc-35-5-10
#
#                                                                                                                               test_split
# dataset                 model                                              facepath
# ff-c23-720-140-140_test net-EfficientNetB4_traindb-ff-c23-720-140-140_f... manipulated_sequences/Deepfakes/c23/videos/134_...       test
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...       test
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...       test
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...       test
#                                                                            manipulated_sequences/Deepfakes/c23/videos/134_...       test
# ...                                                                                                                                  ...
# dfdc-35-5-10_test       net-EfficientNetAutoAttB4ST_traindb-dfdc-35-5-1... dfdc_train_part_47/zpujdfwivh.mp4/fr260_subj2.jpg        test
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr270_subj2.jpg        test
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr279_subj2.jpg        test
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr289_subj2.jpg        test
#                                                                            dfdc_train_part_47/zpujdfwivh.mp4/fr299_subj2.jpg        test
#
# [11905560 rows x 7 columns]

# %% [markdown]
# ## Two models

# %%
print(dataset_list)
# index_list = ['bce_'+dataset_list[0], 'bce_'+dataset_list[1], 'acc_'+dataset_list[0], 'acc_'+dataset_list[1], 'accbal_'+dataset_list[0], 
#               'accbal_'+dataset_list[1], 'rocauc_'+dataset_list[0], 'rocauc_'+dataset_list[1]] # complete index list
index_list = ['bce_'+dataset_list[0], 'bce_'+dataset_list[1], 'rocauc_'+dataset_list[0], 'rocauc_'+dataset_list[1]] # partial index list without accuracies (not important for now)
print(index_list)
# Out:
# ['ff-c23-720-140-140_test', 'dfdc-35-5-10_test']
# ['bce_ff-c23-720-140-140_test', 'bce_dfdc-35-5-10_test', 'rocauc_ff-c23-720-140-140_test', 'rocauc_dfdc-35-5-10_test']

# %% [markdown]
# #### Per video loss

# %%
results_two_df_video = pd.DataFrame(index=index_list)

for comb in tqdm(list(combinations(np.arange(len(model_list)), 2))):
    model_comb = np.asarray(model_list)[list(comb)]
    method = 'two_{:s}_sm'.format(str(comb)[1:-1].replace(', ', '-'))
    results_two_df[method] = np.nan
    if do_distplot:
        print('--------------------------------------------------------------------------------------------------------')
        print(model_comb)
        plt.figure(figsize=(16, 3))
    
    loss = []
#     acc = []
#     accbal = []
    rocauc = []
    for d_idx, dataset in enumerate(dataset_list):
        # Aggregate
        group_df = data_frame_df.loc[dataset].loc[model_comb].groupby('video')
        y_pred = group_df['score'].apply(lambda x: expit(np.mean(np.array(x))))
        y_true = group_df['label'].apply(lambda x: np.array(x)[0])
        
        # Compute loss
        loss.append(log_loss(y_true, y_pred))
#         acc.append(M.accuracy_score(y_true, y_pred>0))
#         accbal.append(M.balanced_accuracy_score(y_true, y_pred>0))
        rocauc.append(M.roc_auc_score(y_true, y_pred))
        rocaucexpit.append(M.roc_auc_score(y_true, expit(y_pred)))
        
        # Plot
        if do_distplot:
            plt.subplot(1, 3, d_idx+1)
            sns.distplot(y_pred[y_true == True], kde_kws={'clip': (0, 1)})
            sns.distplot(y_pred[y_true == False], kde_kws={'clip': (0, 1)})
            plt.title('{:s}: {:.4f}'.format(dataset, loss))
    
    
#     results_two_df.at[index_list, method] = [loss[0], loss[1], acc[0], acc[1], accbal[0], accbal[1], rocauc[0], rocauc[1]]
    results_two_df_videos.at[index_list, method] = [loss[0], loss[1], rocauc[0], rocauc[1]]
    
    if do_distplot:
        plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=66.0), HTML(value='')))

# %% [markdown]
# #### Per frames loss

# %%
from p_tqdm import p_map
results_two_df_frames = pd.DataFrame(index=index_list)

def applyParallel(dfGrouped, func):
    with Pool(12) as p:
        ret_list = p.map(func, [group for name, group in dfGrouped])
    return np.concatenate(ret_list)

def compute_mean_score(x):
    return expit(np.mean(x.to_numpy()))

def compute_label(x):
    return x.to_numpy()[0]

# def compute_partial_results(comb):
#     model_comb = np.asarray(model_list)[list(comb)]
#     method = 'two_{:s}_sm'.format(str(comb)[1:-1].replace(', ', '-'))
#     partial_res = pd.DataFrame(index=index_list)
#     if do_distplot:
#         print('--------------------------------------------------------------------------------------------------------')
#         print(model_comb)
#         plt.figure(figsize=(16, 3))
    
#     loss = []
#     rocauc = []
#     for d_idx, dataset in enumerate(dataset_list):
#         # Aggregate
#         group_df = data_frame_df.loc[dataset].loc[model_comb].groupby('facepath')
#         y_pred = [expit(np.mean(group.to_numpy())) for _, group in group_df['score']]
#         y_true = [group.to_numpy()[0] for _, group in group_df['label']]
        
#         # Compute loss
#         loss.append(log_loss(y_true, y_pred))
#         rocauc.append(M.roc_auc_score(y_true, y_pred))
        
#         # Plot
#         if do_distplot:
#             plt.subplot(1, 3, d_idx+1)
#             sns.distplot(y_pred[y_true == True], kde_kws={'clip': (0, 1)})
#             sns.distplot(y_pred[y_true == False], kde_kws={'clip': (0, 1)})
#             plt.title('{:s}: {:.4f}'.format(dataset, loss))
        
#     partial_res.at[index_list, method] = [loss[0], loss[1], rocauc[0], rocauc[1]]
#     return partial_res

# # with Pool(12) as p:
# #     partial_results = p.map(compute_partial_results, list(combinations(np.arange(len(model_list)), 2)))

# partial_results = p_map(compute_partial_results, list(combinations(np.arange(len(model_list)), 2)), num_cpus=12)

# results_two_df_frames = pd.concat(partial_results)
    
for comb in tqdm(list(combinations(np.arange(len(model_list)), 2))):
    model_comb = np.asarray(model_list)[list(comb)]
    method = 'two_{:s}_sm'.format(str(comb)[1:-1].replace(', ', '-'))
    results_two_df_frames[method] = np.nan
    if do_distplot:
        print('--------------------------------------------------------------------------------------------------------')
        print(model_comb)
        plt.figure(figsize=(16, 3))
    
    loss = []
    rocauc = []
    for d_idx, dataset in enumerate(dataset_list):
        # Aggregate
        group_df = data_frame_df.loc[dataset].loc[model_comb].groupby('facepath')
        y_pred = applyParallel(group_df['label'], compute_mean_score)
        y_true = applyParallel(group_df['label'], compute_label)
        
        # Compute loss
        loss.append(log_loss(y_true, y_pred))
        rocauc.append(M.roc_auc_score(y_true, y_pred))
        
        # Plot
        if do_distplot:
            plt.subplot(1, 3, d_idx+1)
            sns.distplot(y_pred[y_true == True], kde_kws={'clip': (0, 1)})
            sns.distplot(y_pred[y_true == False], kde_kws={'clip': (0, 1)})
            plt.title('{:s}: {:.4f}'.format(dataset, loss))
    
    
    results_two_df_frames.at[index_list, method] = [loss[0], loss[1], rocauc[0], rocauc[1]]
    
    if do_distplot:
        plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=66.0), HTML(value='')))
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-10:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f0ac6029c14f> in <module>
#      65         # Aggregate
#      66         group_df = data_frame_df.loc[dataset].loc[model_comb].groupby('facepath')
# ---> 67         y_pred = applyParallel(group_df['label'], compute_mean_score)
#      68         y_true = applyParallel(group_df['label'], compute_label)
#      69
#
# <ipython-input-15-f0ac6029c14f> in applyParallel(dfGrouped, func)
#       4 def applyParallel(dfGrouped, func):
#       5     with Pool(12) as p:
# ----> 6         ret_list = p.map(func, [group for name, group in dfGrouped])
#       7     return np.concatenate(ret_list)
#       8
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
results_two_df_frames
# Out:
#                                 two_0-1_sm  two_0-2_sm  two_0-3_sm  \
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# bce_dfdc-35-5-10_test                  NaN         NaN         NaN
# rocauc_ff-c23-720-140-140_test    0.919543         NaN         NaN
# rocauc_dfdc-35-5-10_test          0.827018         NaN         NaN
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# ...                                    ...         ...         ...
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# bce_dfdc-35-5-10_test                  NaN         NaN         NaN
# rocauc_ff-c23-720-140-140_test         NaN         NaN         NaN
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
#
#                                 two_0-4_sm  two_0-5_sm  two_0-6_sm  \
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# bce_dfdc-35-5-10_test                  NaN         NaN         NaN
# rocauc_ff-c23-720-140-140_test         NaN         NaN         NaN
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# ...                                    ...         ...         ...
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# bce_dfdc-35-5-10_test                  NaN         NaN         NaN
# rocauc_ff-c23-720-140-140_test         NaN         NaN         NaN
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
#
#                                 two_0-7_sm  two_0-8_sm  two_0-9_sm  \
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# bce_dfdc-35-5-10_test                  NaN         NaN         NaN
# rocauc_ff-c23-720-140-140_test         NaN         NaN         NaN
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# ...                                    ...         ...         ...
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
# bce_ff-c23-720-140-140_test            NaN         NaN         NaN
# bce_dfdc-35-5-10_test                  NaN         NaN         NaN
# rocauc_ff-c23-720-140-140_test         NaN         NaN         NaN
# rocauc_dfdc-35-5-10_test               NaN         NaN         NaN
#
#                                 two_0-10_sm  ...  two_7-8_sm  two_7-9_sm  \
# bce_ff-c23-720-140-140_test             NaN  ...         NaN         NaN
# bce_dfdc-35-5-10_test                   NaN  ...         NaN         NaN
# rocauc_ff-c23-720-140-140_test          NaN  ...         NaN         NaN
# rocauc_dfdc-35-5-10_test                NaN  ...         NaN         NaN
# bce_ff-c23-720-140-140_test             NaN  ...         NaN         NaN
# ...                                     ...  ...         ...         ...
# rocauc_dfdc-35-5-10_test                NaN  ...         NaN         NaN
# bce_ff-c23-720-140-140_test             NaN  ...         NaN         NaN
# bce_dfdc-35-5-10_test                   NaN  ...         NaN         NaN
# rocauc_ff-c23-720-140-140_test          NaN  ...         NaN         NaN
# rocauc_dfdc-35-5-10_test                NaN  ...         NaN         NaN
#
#                                 two_7-10_sm  two_7-11_sm  two_8-9_sm  \
# bce_ff-c23-720-140-140_test             NaN          NaN         NaN
# bce_dfdc-35-5-10_test                   NaN          NaN         NaN
# rocauc_ff-c23-720-140-140_test          NaN          NaN         NaN
# rocauc_dfdc-35-5-10_test                NaN          NaN         NaN
# bce_ff-c23-720-140-140_test             NaN          NaN         NaN
# ...                                     ...          ...         ...
# rocauc_dfdc-35-5-10_test                NaN          NaN         NaN
# bce_ff-c23-720-140-140_test             NaN          NaN         NaN
# bce_dfdc-35-5-10_test                   NaN          NaN         NaN
# rocauc_ff-c23-720-140-140_test          NaN          NaN         NaN
# rocauc_dfdc-35-5-10_test                NaN          NaN         NaN
#
#                                 two_8-10_sm  two_8-11_sm  two_9-10_sm  \
# bce_ff-c23-720-140-140_test             NaN          NaN          NaN
# bce_dfdc-35-5-10_test                   NaN          NaN          NaN
# rocauc_ff-c23-720-140-140_test          NaN          NaN          NaN
# rocauc_dfdc-35-5-10_test                NaN          NaN          NaN
# bce_ff-c23-720-140-140_test             NaN          NaN          NaN
# ...                                     ...          ...          ...
# rocauc_dfdc-35-5-10_test                NaN          NaN          NaN
# bce_ff-c23-720-140-140_test             NaN          NaN          NaN
# bce_dfdc-35-5-10_test                   NaN          NaN          NaN
# rocauc_ff-c23-720-140-140_test          NaN          NaN          NaN
# rocauc_dfdc-35-5-10_test                NaN          NaN          NaN
#
#                                 two_9-11_sm  two_10-11_sm
# bce_ff-c23-720-140-140_test             NaN           NaN
# bce_dfdc-35-5-10_test                   NaN           NaN
# rocauc_ff-c23-720-140-140_test          NaN           NaN
# rocauc_dfdc-35-5-10_test                NaN           NaN
# bce_ff-c23-720-140-140_test             NaN           NaN
# ...                                     ...           ...
# rocauc_dfdc-35-5-10_test           0.862528           NaN
# bce_ff-c23-720-140-140_test             NaN           NaN
# bce_dfdc-35-5-10_test                   NaN           NaN
# rocauc_ff-c23-720-140-140_test          NaN      0.658942
# rocauc_dfdc-35-5-10_test                NaN      0.849556
#
# [264 rows x 66 columns]

# %%
comb = list(combinations(np.arange(len(model_list)), 2))
model_comb = np.asarray(model_list)[list(comb[0])]
group_df = data_frame_df.loc[dataset_list[1]].loc[model_comb].groupby('facepath')

# %%
iterator = group_df['score'].__iter__()
groups = [expit(np.mean(group.to_numpy())) for _, group in group_df['score']]
groups_label = [group.to_numpy()[0] for _, group in group_df['label']]
# print(name, group)
# print(groups)

# %%
print(type(groups[0]))
print(groups[0], len(groups))
print(type(groups_label[0]))
print(groups_label[0], len(groups_label))
print(log_loss(groups_label, groups))
print(M.roc_auc_score(groups_label, groups))
# Out:
# <class 'numpy.float32'>
# 0.60053957 949084
# <class 'numpy.bool_'>
# True 949084
# 0.7129541360267244
# 0.8270184246448854

# %%
results_two_df_frames.T.style.apply(highlight_values)
# Out:
# <style  type="text/css" >
#     #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col1 {
#             background-color:  green;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow14_col3 {
#             background-color:  green;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow14_col5 {
#             background-color:  green;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow19_col2 {
#             background-color:  red;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow19_col4 {
#             background-color:  red;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow24_col0 {
#             background-color:  red;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow24_col2 {
#             background-color:  green;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow24_col4 {
#             background-color:  green;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow31_col1 {
#             background-color:  red;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow41_col3 {
#             background-color:  red;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow41_col5 {
#             background-color:  red;
#         }    #T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow48_col0 {
#             background-color:  green;
#         }</style><table id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >bce_ff-c23-720-140-140_test</th>        <th class="col_heading level0 col1" >bce_dfdc-35-5-10_test</th>        <th class="col_heading level0 col2" >rocauc_ff-c23-720-140-140_test</th>        <th class="col_heading level0 col3" >rocauc_dfdc-35-5-10_test</th>        <th class="col_heading level0 col4" >rocaucexpit_ff-c23-720-140-140_test</th>        <th class="col_heading level0 col5" >rocaucexpit_dfdc-35-5-10_test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row0" class="row_heading level0 row0" >two_0-1_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow0_col0" class="data row0 col0" >0.336162</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow0_col1" class="data row0 col1" >0.569402</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow0_col2" class="data row0 col2" >0.951224</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow0_col3" class="data row0 col3" >0.904609</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow0_col4" class="data row0 col4" >0.951224</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow0_col5" class="data row0 col5" >0.904609</td>
#             </tr>
#             <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row1" class="row_heading level0 row1" >two_0-2_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col0" class="data row1 col0" >0.231045</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col1" class="data row1 col1" >1.210614</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col2" class="data row1 col2" >0.969713</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col3" class="data row1 col3" >0.723877</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col4" class="data row1 col4" >0.969713</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow1_col5" class="data row1 col5" >0.723877</td>
#             </tr>
#             <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row2" class="row_heading level0 row2" >two_0-3_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow2_col0" class="data row2 col0" >0.353878</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow2_col1" class="data row2 col1" >0.439426</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow2_col2" class="data row2 col2" >0.942449</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow2_col3" class="data row2 col3" >0.929469</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow2_col4" class="data row2 col4" >0.942449</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow2_col5" class="data row2 col5" >0.929469</td>
#             </tr>
#             <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row3" class="row_heading level0 row3" >two_0-4_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow3_col0" class="data row3 col0" >0.245556</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow3_col1" class="data row3 col1" >1.170922</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow3_col2" class="data row3 col2" >0.967895</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow3_col3" class="data row3 col3" >0.722120</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow3_col4" class="data row3 col4" >0.967895</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow3_col5" class="data row3 col5" >0.722120</td>
#             </tr>
#             <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row4" class="row_heading level0 row4" >two_0-5_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow4_col0" class="data row4 col0" >0.377685</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow4_col1" class="data row4 col1" >0.433455</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow4_col2" class="data row4 col2" >0.942551</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow4_col3" class="data row4 col3" >0.934999</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow4_col4" class="data row4 col4" >0.942551</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow4_col5" class="data row4 col5" >0.934999</td>
#             </tr>
#             <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row5" class="row_heading level0 row5" >two_0-6_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow5_col0" class="data row5 col0" >0.217130</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow5_col1" class="data row5 col1" >1.192079</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow5_col2" class="data row5 col2" >0.972392</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow5_col3" class="data row5 col3" >0.745298</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow5_col4" class="data row5 col4" >0.972392</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow5_col5" class="data row5 col5" >0.745298</td>
#             </tr>
#             <tr>
#                         <th id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8ablevel0_row6" class="row_heading level0 row6" >two_0-7_sm</th>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow6_col0" class="data row6 col0" >0.232154</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow6_col1" class="data row6 col1" >1.158846</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow6_col2" class="data row6 col2" >0.968342</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow6_col3" class="data row6 col3" >0.726571</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow6_col4" class="data row6 col4" >0.968342</td>
#                         <td id="T_631d2a0e_7bd0_11ea_b248_15cff98ed8abrow6_col5" class="data row6 col5" >0.72657

# %% [markdown]
# ### Weight two models

# %%
def get_best_loss_weights(y_true, y_pred):
    loss_list = []
    a_list = np.linspace(0, 1, 30)
    for a in a_list:
        loss_list.append( log_loss(y_true, expit(y_pred.T.dot([a, 1-a])) ) )
    best_idx = np.argmin(loss_list)
    return loss_list[best_idx], a_list[best_idx]

def get_best_rocauc_weights(y_true, y_pred):
    auc_list = []
    a_list = np.linspace(0, 1, 30)
    for a in a_list:
        loss_list.append(M.roc_auc_score(y_true, y_pred.T.dot([a, 1-a])))
    best_idx = np.argmin(loss_list)
    return loss_list[best_idx], a_list[best_idx]

def get_best_rocaucexpit_weights(y_true, y_pred):
    auc_list = []
    a_list = np.linspace(0, 1, 30)
    for a in a_list:
        loss_list.append(M.roc_auc_score(y_true, expit(y_pred.T.dot([a, 1-a]))))
    best_idx = np.argmin(loss_list)
    return loss_list[best_idx], a_list[best_idx]

# %%
# Aggregate
loss_list = []
comb_list = []
model_comb_list = []
a_list = []
for comb in tqdm(list(combinations(np.arange(len(model_list)), 2))):
    model_comb = np.asarray(model_list)[list(comb)]
    y_pred = []
    y_true = []
    for model in model_comb:
        group_df = data_frame_df.loc['dfdc_val'].loc[model].groupby('video')
        y_pred.append(group_df['score'].apply(lambda x: np.array(x).mean()))
        y_true.append(group_df['label'].apply(lambda x: np.array(x)[0]))
    y_true = np.array(y_true).mean(axis=0)
    y_pred = np.array(y_pred)
    loss, a = get_best_weights(y_true, y_pred)
    
    
    loss_list.append(loss)
    a_list.append(a)
    comb_list.append(comb)
    model_comb_list.append(model_comb)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=66.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dfdc_val'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9d71a9089529> in <module>
#       9     y_true = []
#      10     for model in model_comb:
# ---> 11         group_df = data_frame_df.loc['dfdc_val'].loc[model].groupby('video')
#      12         y_pred.append(group_df['score'].apply(lambda x: np.array(x).mean()))
#      13         y_true.append(group_df['label'].apply(lambda x: np.array(x)[0]))
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1764
#    1765             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1766             return self._getitem_axis(maybe_callable, axis=axis)
#    1767
#    1768     def _is_scalar_access(self, key: Tuple):
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1961         # fall thru to straight lookup
#    1962         self._validate_key(key, axis)
# -> 1963         return self._get_label(key, axis=axis)
#    1964
#    1965
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3532         index = self.index
#    3533         if isinstance(index, MultiIndex):
# -> 3534             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3535         else:
#    3536             loc = self.index.get_loc(key)
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2835                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    2836         else:
# -> 2837             indexer = self._get_level_indexer(key, level=level)
#    2838             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    2839
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2918         else:
#    2919
# -> 2920             code = self._get_loc_single_level_index(level_index, key)
#    2921
#    2922             if level > 0 or self.lexsort_depth == 0:
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2587             return -1
#    2588         else:
# -> 2589             return level_index.get_loc(key)
#    2590
#    2591     def get_loc(self, key, method=None):
#
# /nas/home/ecannas/miniconda3/envs/dfdc/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dfdc_val'

# %%
#print(loss_list)
#print(a_list)
#print(comb_list)
#print()

idx = np.argmin(loss_list)
print(model_comb_list[idx])
print(loss_list[idx], a_list[idx])
